# %% [markdown]
# ---
# layout: post
# title: 5 things I did this trimester
# description:  Final
# type: issues
# comments: true
# ---

# %% [markdown]
# # 5 things that I did over 12 weeks

# %% [markdown]
# ## 1st thing:
#
# The first thing I did was designing the backend for the leaderboard functionality, this included saving user's data from a seperate api and running it through a math function to calculate the score.
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## 2nd thing:
#
# The second thing I did was partially design the frontend for the posts.py and for the competition.py, along with fully desigining the leaderboard frontend
#
# ![image.png](attachment:image.png)
# here i designed the buttons and the displaying for the word the user will draw, along with the timer displaying (competition)
#
# ![image-2.png](attachment:image-2.png)
# here I fully designed the leaderboard with real data shown below the submission, there is a manual input, but it also automatically inputs. (leaderboard)
#
# ![image-3.png](attachment:image-3.png)
# here I designed the box width and how the images are displayed in the frontend. (posts)

# %% [markdown]
# ## 3rd thing:
#
# The second thing I did was design the backend admin tables which included crud functionality for them
#
# ![image-3.png](attachment:image-3.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## 4th thing I did:
#
# The third thing I did was create burdown lists for myself, and for the backend workers, along with our team grading issue from the past
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 5th thing I did:
#
# The fourth thing I did was style our Index page on the backend for better usability for the group.
#
# ![alt text](<Screenshot 2025-03-01 131243.png>)

# %% [markdown]
# ## extra
#
# The fifth thing I did was at the N@tm where I interviewed some groups and gave feedback on other groups
#
# <video width="100%" controls>
#     <source src="/home/daksha_gowda/nighthawk/dakshaggCSP_2025/images/videos/IMG_4996.mp4" type="video/mp4">
#     Your browser does not support the video tag.
# </video>
#
# ![image.png](https://i.ibb.co/Zz5bzf4V/IMG-4992.jpg)
#
# ![image.png](https://i.ibb.co/Y7hHnL9G/IMG-5605.jpg)
