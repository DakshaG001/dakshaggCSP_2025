# %% [markdown]
# # 5 things that I did over 12 weeks

# %% [markdown]
# ## 1st thing:
#
# The first thing that I did was design the leaderboard, consisting of the leaderboard api, the frontend, and the backend
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 2nd thing:
#
# The second thing I did was design the backend site, this meant customizing the index page, and adding admin tables for admines to do crud operations
#
# ![image.png](attachment:image.png)
# ![image-3.png](attachment:image-3.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## 3rd thing I did:
#
# The third thing I did was create burdown lists for myself, and for the backend workers, along with our team grading issue from the past
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 4th thing I did:
#
# The fourth thing I did was present our project to other groups at the N@tm

# %% [markdown]
# ## 5th thing I did:
#
# The fifth thing I did was at the N@tm where I interviewed some groups and gave feedback on other groups
#
# <video controls src="IMG_4996.mp4" title="Title"></video>
